# %% [markdown]
# <a href="https://colab.research.google.com/github/LashenDEV/AIML/blob/main/tensorflow01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import data**

# %%
import pandas as pd
url = ("https://raw.githubusercontent.com/selva86/datasets/master/Ionosphere.csv")
df = pd.read_csv(url)
df.head(5)
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 0 -0.54487  0.18641 -0.45300      1
# 1 -0.06288 -0.13738 -0.02447      0
# 2 -0.24180  0.56045 -0.38238      1
# 3  1.00000 -0.32382  1.00000      0
# 4 -0.59573 -0.04608 -0.65697      1
#
# [5 rows x 35 columns]

# %%
x = df.drop(['Class'], axis=1)
y = df['Class']
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 346    1
# 347    1
# 348    1
# 349    1
# 350    1
# Name: Class, Length: 351, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %% [markdown]
# **Import** **Dependencies**

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout

# %% [markdown]
# **Build Model**

# %%
model=Sequential()
model.add(Dense(units=10, activation="relu", input_dim=len(x_train.columns)))
model.add(Dense(units=5, activation="relu"))
model.add(Dense(units=1, activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                350
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 411
# Trainable params: 411
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy", optimizer="sgd", metrics="accuracy")

# %%
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 0s 29ms/step - loss: 0.6920 - accuracy: 0.3821 - val_loss: 0.6896 - val_accuracy: 0.4085
# Epoch 2/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6685 - accuracy: 0.4321 - val_loss: 0.6678 - val_accuracy: 0.5070
# Epoch 3/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6518 - accuracy: 0.5786 - val_loss: 0.6528 - val_accuracy: 0.7183
# Epoch 4/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6412 - accuracy: 0.7286 - val_loss: 0.6446 - val_accuracy: 0.7606
# Epoch 5/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6352 - accuracy: 0.7607 - val_loss: 0.6403 - val_accuracy: 0.7606
# Epoch 6/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6312 - accuracy: 0.7929 - val_loss: 0.6371 - val_accuracy: 0.7887
# Epoch 7/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6279 - accuracy: 0.7964 - val_loss: 0.6342 - val_accuracy: 0.8169
# Epoch 8/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6249 - accuracy: 0.8036 - val_loss: 0.6316 - val_accuracy: 0.8169
# Epoch 9/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6219 - accuracy: 0.8000 - val_loss: 0.6290 - val_accuracy: 0.8028
# Epoch 10/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6191 - accuracy: 0.8000 - val_loss: 0.6267 - val_accuracy: 0.8028
# Epoch 11/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6164 - accuracy: 0.7964 - val_loss: 0.6244 - val_accuracy: 0.8169
# Epoch 12/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6138 - accuracy: 0.7964 - val_loss: 0.6221 - val_accuracy: 0.7887
# Epoch 13/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6111 - accuracy: 0.7929 - val_loss: 0.6199 - val_accuracy: 0.7887
# Epoch 14/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6087 - accuracy: 0.8071 - val_loss: 0.6179 - val_accuracy: 0.8028
# Epoch 15/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6063 - accuracy: 0.8071 - val_loss: 0.6157 - val_accuracy: 0.8169
# Epoch 16/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6037 - accuracy: 0.8071 - val_loss: 0.6136 - val_accuracy: 0.8169
# Epoch 17/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6014 - accuracy: 0.8071 - val_loss: 0.6116 - val_accuracy: 0.8169
# Epoch 18/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5992 - accuracy: 0.8071 - val_loss: 0.6096 - val_accuracy: 0.8169
# Epoch 19/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5967 - accuracy: 0.8107 - val_loss: 0.6077 - val_accuracy: 0.8169
# Epoch 20/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5945 - accuracy: 0.8107 - val_loss: 0.6057 - val_accuracy: 0.8169
# Epoch 21/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5922 - accuracy: 0.8143 - val_loss: 0.6039 - val_accuracy: 0.8169
# Epoch 22/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5900 - accuracy: 0.8143 - val_loss: 0.6021 - val_accuracy: 0.8169
# Epoch 23/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5878 - accuracy: 0.8143 - val_loss: 0.6002 - val_accuracy: 0.8169
# Epoch 24/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5856 - accuracy: 0.8143 - val_loss: 0.5983 - val_accuracy: 0.8169
# Epoch 25/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5835 - accuracy: 0.8179 - val_loss: 0.5964 - val_accuracy: 0.8169
# Epoch 26/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5813 - accuracy: 0.8179 - val_loss: 0.5945 - val_accuracy: 0.8169
# Epoch 27/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5792 - accuracy: 0.8214 - val_loss: 0.5926 - val_accuracy: 0.7887
# Epoch 28/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5770 - accuracy: 0.8214 - val_loss: 0.5907 - val_accuracy: 0.7887
# Epoch 29/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5749 - accuracy: 0.8214 - val_loss: 0.5889 - val_accuracy: 0.7887
# Epoch 30/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5728 - accuracy: 0.8214 - val_loss: 0.5871 - val_accuracy: 0.7887
# Epoch 31/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5707 - accuracy: 0.8214 - val_loss: 0.5852 - val_accuracy: 0.8028
# Epoch 32/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5686 - accuracy: 0.8179 - val_loss: 0.5833 - val_accuracy: 0.8028
# Epoch 33/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5666 - accuracy: 0.8179 - val_loss: 0.5815 - val_accuracy: 0.8028
# Epoch 34/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5646 - accuracy: 0.8179 - val_loss: 0.5797 - val_accuracy: 0.8028
# Epoch 35/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5625 - accuracy: 0.8179 - val_loss: 0.5778 - val_accuracy: 0.8028
# Epoch 36/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5605 - accuracy: 0.8179 - val_loss: 0.5760 - val_accuracy: 0.8028
# Epoch 37/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5583 - accuracy: 0.8214 - val_loss: 0.5741 - val_accuracy: 0.8028
# Epoch 38/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5562 - accuracy: 0.8214 - val_loss: 0.5723 - val_accuracy: 0.8028
# Epoch 39/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5541 - accuracy: 0.8250 - val_loss: 0.5703 - val_accuracy: 0.8028
# Epoch 40/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5520 - accuracy: 0.8214 - val_loss: 0.5685 - val_accuracy: 0.8169
# Epoch 41/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5498 - accuracy: 0.8214 - val_loss: 0.5667 - val_accuracy: 0.8169
# Epoch 42/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5476 - accuracy: 0.8250 - val_loss: 0.5647 - val_accuracy: 0.8169
# Epoch 43/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5454 - accuracy: 0.8214 - val_loss: 0.5627 - val_accuracy: 0.8169
# Epoch 44/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5432 - accuracy: 0.8250 - val_loss: 0.5607 - val_accuracy: 0.8451
# Epoch 45/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5410 - accuracy: 0.8250 - val_loss: 0.5587 - val_accuracy: 0.8451
# Epoch 46/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5387 - accuracy: 0.8250 - val_loss: 0.5568 - val_accuracy: 0.8451
# Epoch 47/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5365 - accuracy: 0.8286 - val_loss: 0.5547 - val_accuracy: 0.8451
# Epoch 48/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5342 - accuracy: 0.8321 - val_loss: 0.5525 - val_accuracy: 0.8451
# Epoch 49/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5319 - accuracy: 0.8286 - val_loss: 0.5505 - val_accuracy: 0.8451
# Epoch 50/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5297 - accuracy: 0.8321 - val_loss: 0.5484 - val_accuracy: 0.8451
# Epoch 51/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5274 - accuracy: 0.8321 - val_loss: 0.5463 - val_accuracy: 0.8451
# Epoch 52/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5250 - accuracy: 0.8321 - val_loss: 0.5443 - val_accuracy: 0.8451
# Epoch 53/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5228 - accuracy: 0.8357 - val_loss: 0.5420 - val_accuracy: 0.8451
# Epoch 54/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5205 - accuracy: 0.8357 - val_loss: 0.5399 - val_accuracy: 0.8451
# Epoch 55/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5182 - accuracy: 0.8357 - val_loss: 0.5378 - val_accuracy: 0.8451
# Epoch 56/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5158 - accuracy: 0.8357 - val_loss: 0.5357 - val_accuracy: 0.8451
# Epoch 57/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5134 - accuracy: 0.8357 - val_loss: 0.5334 - val_accuracy: 0.8592
# Epoch 58/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.8357 - val_loss: 0.5312 - val_accuracy: 0.8592
# Epoch 59/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5088 - accuracy: 0.8357 - val_loss: 0.5292 - val_accuracy: 0.8451
# Epoch 60/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5064 - accuracy: 0.8393 - val_loss: 0.5270 - val_accuracy: 0.8451
# Epoch 61/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5041 - accuracy: 0.8393 - val_loss: 0.5246 - val_accuracy: 0.8451
# Epoch 62/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5016 - accuracy: 0.8464 - val_loss: 0.5225 - val_accuracy: 0.8451
# Epoch 63/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4994 - accuracy: 0.8464 - val_loss: 0.5203 - val_accuracy: 0.8592
# Epoch 64/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4970 - accuracy: 0.8500 - val_loss: 0.5180 - val_accuracy: 0.8592
# Epoch 65/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4946 - accuracy: 0.8500 - val_loss: 0.5157 - val_accuracy: 0.8592
# Epoch 66/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4922 - accuracy: 0.8500 - val_loss: 0.5137 - val_accuracy: 0.8592
# Epoch 67/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4898 - accuracy: 0.8500 - val_loss: 0.5115 - val_accuracy: 0.8592
# Epoch 68/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4874 - accuracy: 0.8500 - val_loss: 0.5095 - val_accuracy: 0.8592
# Epoch 69/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4851 - accuracy: 0.8500 - val_loss: 0.5071 - val_accuracy: 0.8592
# Epoch 70/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4827 - accuracy: 0.8500 - val_loss: 0.5047 - val_accuracy: 0.8592
# Epoch 71/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4803 - accuracy: 0.8500 - val_loss: 0.5026 - val_accuracy: 0.8592
# Epoch 72/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4779 - accuracy: 0.8500 - val_loss: 0.5004 - val_accuracy: 0.8592
# Epoch 73/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4755 - accuracy: 0.8536 - val_loss: 0.4981 - val_accuracy: 0.8592
# Epoch 74/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4730 - accuracy: 0.8536 - val_loss: 0.4961 - val_accuracy: 0.8592
# Epoch 75/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4708 - accuracy: 0.8536 - val_loss: 0.4939 - val_accuracy: 0.8592
# Epoch 76/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4682 - accuracy: 0.8536 - val_loss: 0.4917 - val_accuracy: 0.8592
# Epoch 77/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4659 - accuracy: 0.8607 - val_loss: 0.4894 - val_accuracy: 0.8592
# Epoch 78/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4636 - accuracy: 0.8643 - val_loss: 0.4870 - val_accuracy: 0.8592
# Epoch 79/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4610 - accuracy: 0.8643 - val_loss: 0.4847 - val_accuracy: 0.8592
# Epoch 80/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4587 - accuracy: 0.8643 - val_loss: 0.4824 - val_accuracy: 0.8592
# Epoch 81/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4563 - accuracy: 0.8643 - val_loss: 0.4802 - val_accuracy: 0.8592
# Epoch 82/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4539 - accuracy: 0.8679 - val_loss: 0.4780 - val_accuracy: 0.8592
# Epoch 83/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4515 - accuracy: 0.8607 - val_loss: 0.4760 - val_accuracy: 0.8592
# Epoch 84/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4490 - accuracy: 0.8750 - val_loss: 0.4734 - val_accuracy: 0.8592
# Epoch 85/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4467 - accuracy: 0.8750 - val_loss: 0.4711 - val_accuracy: 0.8592
# Epoch 86/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.4444 - accuracy: 0.8714 - val_loss: 0.4690 - val_accuracy: 0.8592
# Epoch 87/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4420 - accuracy: 0.8786 - val_loss: 0.4670 - val_accuracy: 0.8592
# Epoch 88/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4395 - accuracy: 0.8786 - val_loss: 0.4647 - val_accuracy: 0.8592
# Epoch 89/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4373 - accuracy: 0.8786 - val_loss: 0.4625 - val_accuracy: 0.8592
# Epoch 90/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4349 - accuracy: 0.8786 - val_loss: 0.4605 - val_accuracy: 0.8592
# Epoch 91/100
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4326 - accuracy: 0.8750 - val_loss: 0.4582 - val_accuracy: 0.8592
# Epoch 92/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4302 - accuracy: 0.8750 - val_loss: 0.4560 - val_accuracy: 0.8592
# Epoch 93/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4281 - accuracy: 0.8821 - val_loss: 0.4539 - val_accuracy: 0.8592
# Epoch 94/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4256 - accuracy: 0.8750 - val_loss: 0.4520 - val_accuracy: 0.8592
# Epoch 95/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4234 - accuracy: 0.8857 - val_loss: 0.4493 - val_accuracy: 0.8592
# Epoch 96/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4210 - accuracy: 0.8821 - val_loss: 0.4472 - val_accuracy: 0.8592
# Epoch 97/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4186 - accuracy: 0.8821 - val_loss: 0.4449 - val_accuracy: 0.8592
# Epoch 98/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4164 - accuracy: 0.8821 - val_loss: 0.4425 - val_accuracy: 0.8592
# Epoch 99/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4140 - accuracy: 0.8821 - val_loss: 0.4403 - val_accuracy: 0.8732
# Epoch 100/100
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4116 - accuracy: 0.8821 - val_loss: 0.4382 - val_accuracy: 0.8732

# %%
model.save('weights.h5')
